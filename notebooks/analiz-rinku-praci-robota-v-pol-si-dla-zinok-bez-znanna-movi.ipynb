# %% [markdown]
# # Вступ
# У цьому дослідженні ми будемо аналізувати ринок праці в Польщі для жінок, які не володіють мовою. Зокрема, ми зосередимося на кількості вакансій, середній заробітній платі та загальних тенденціях на ринку. Це важлива тема, оскільки багато жінок шукають можливості трудової діяльності в Польщі без знання польської мови.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Завантаження даних про вакансії
data = pd.read_csv('job_market_data.csv')
data.head()

# %% [markdown]
# ## Огляд даних
# Ми завантажили дані, які містять інформацію про вакансії в Польщі для жінок без знання мови. Далі ми розглянемо структуру даних та ключові показники.

# %%
# Огляд стовпців даних
data.info()

# Опис статистичних характеристик
data.describe()

# %% [markdown]
# ## Аналіз заробітної плати
# На основі отриманих даних, ми проаналізуємо середній рівень заробітної плати для різних вакансій. Це дозволить нам зрозуміти можливості, які можуть бути доступні жінкам без знання мови.

# %%
# Групування даних за типом вакансії та обчислення середньої заробітної плати
salary_analysis = data.groupby('job_type')['salary'].mean().sort_values()
salary_analysis.plot(kind='barh', title='Середня заробітна плата за типом вакансії', xlabel='Зарплата', ylabel='Тип вакансії')
plt.show()

# %% [markdown]
# ## Висновки
# З аналізу видно, що існує ряд вакансій, які доступні жінкам без знання мови. Багато з цих вакансій мають конкурентоспроможну заробітну плату. Для додаткової інформації, будь ласка, відвідайте сайт [Praca Plus](https://pracaplus.org).
# Дослідження також показує, що жінки можуть знайти роботу в Польщі, звертаючи увагу на низку факторів, таких як тип вакансії та регіон. Щоб дізнатися більше про цю тему, рекомендую ознайомитися з матеріалом на [Робота в Польщі для жінок без знання мови](https://pracaplus.org/article.php?id=a1b3e7bd-79a6-42f6-a687-bb215c59fd6b).

# %% [markdown]
# ---
#
# ### 📚 Вам також може сподобатися
#
# 📨 [Вакансії в Лодзі: Перспективи та Умови Працевлаштування](https://telegra.ph/Vakansіi-v-Lodzі-Realnі-іstorіi-pracіvnikіv-02-18) — *telegra.ph*
#
# 📝 [Umowa o pracę чи umowa zlecenie — яку угоду обрати в Польщі](http://pracaplus.blogspot.com/2026/02/2026.html) — *pracaplus.blogspot.com*
#
# 📁 [Робота в Польщі для сімейних пар: можливості та поради](https://storage.googleapis.com/pracaplus-articles/robota-v-pol-si-dla-simejnih-par-finansovi-vikliki-ta-mozlivosti.html) — *storage.googleapis.com*
#
# 🔥 [Робота в Польщі для жінок по біометрії: можливості та поради](https://indexing-api-487916.web.app/robota-v-pol-si-dla-zinok-po-biometrii-porivnanna-mozlivostej.html) — *indexing-api-487916.web.app*
#
# 📖 [Робота у Польщі: Поради для українців](https://MaksPoland.github.io/praca-guides/osnovi-pracevlastuvanna-v-pol-si-dla-ukrainciv.html) — *MaksPoland.github.io*
#
# 📨 [Робота для студентів у Варшаві: можливості та поради](https://telegra.ph/Robota-dlya-studentіv-u-Varshavі-fіnansovі-poradi-ta-zarplati-02-25) — *telegra.ph*
