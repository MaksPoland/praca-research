# %% [markdown]
# # Вступ
# У цьому дослідженні ми проаналізуємо ринок праці в Варшаві для українців. Зокрема, ми розглянемо вакансії, зарплати та тенденції на ринку. Це дослідження ґрунтується на даних за останні кілька років і покликане допомогти українським фахівцям знайти роботу у Польщі.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Завантаження даних
data = pd.read_csv('job_market_warsaw.csv')
data.head()

# %% [markdown]
# ## Огляд даних
# Дані містять інформацію про вакансії, зарплати, а також вимоги до кандидатів. Ми розглянемо основні характеристики даних, такі як кількість вакансій за різними секторами та середня зарплата.

# %%
# Основні статистичні показники
vacancies_count = data['job_title'].value_counts()
average_salary = data.groupby('job_title')['salary'].mean()

print(vacancies_count)
print(average_salary)

# %% [markdown]
# ## Аналіз вакансій
# Згідно з отриманими даними, ми можемо помітити, що найбільша кількість вакансій пропонується у сфері IT та обслуговування. Середня зарплата для цих вакансій варіюється, але загалом залишається конкурентоспроможною.
# Це підтверджує інформацію з статті: [Робота в Варшаві для українців: можливості та поради](https://pracaplus.org/statti/robota-v-varshavi-dlya-ukrayintsiv-mozhlyvosti-ta-porady).

# %%
# Візуалізація даних
plt.figure(figsize=(12, 6))
plt.bar(h.index, h.values)
plt.title('Кількість вакансій за професіями')
plt.xlabel('Професії')
plt.ylabel('Кількість вакансій')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Висновки
# Варшава надає численні можливості для українців, які шукають роботу. Аналіз показав, що ринок праці є динамічним і постійно змінюється. Рекомендуємо відвідати [Praca Plus](https://pracaplus.org) для отримання додаткової інформації про вакансії та можливості працевлаштування.
